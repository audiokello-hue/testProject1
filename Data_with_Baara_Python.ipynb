# %% [markdown]
# <a href="https://colab.research.google.com/github/audiokello-hue/testProject1/blob/master/Data_with_Baara_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Learning Python with Baara.
print("Hey my name is Audi")
# Out:
# Hey my name is Audi

# %%
# special characters

# \" --->

print("Hi \"Python\"")  #Output : Hi "Python" ... this will give similar output print("Hi 'Python'"),

# \' --->
print('Hi \'Python\'')

# \\ --->

print("Username: C:\\User\\Audi")

# \n --->
print("message1\n\nmessage2")

# \t --->

print("message1\tmessage2")

# \b --->

#Execerise
# Use print() to recreate this exact output. You are allowed to use only one print()

print("""Your learning path:
\t-Python Bsacis
\t-Data Engineering
\t-AI""")

# use of \n\t
print("""Your learning path:
\n\t-Python Bsacis
\n\t-Data Engineering
\n\t-AI""")
# Out:
# Hi "Python"
# Hi 'Python'
# Username: C:\User\Audi
# message1
#
# message2
# message1	message2
# Your learning path:
# 	-Python Bsacis
# 	-Data Engineering
# 	-AI
# Your learning path:
#
# 	-Python Bsacis
#
# 	-Data Engineering
#
# 	-AI

# %%
# Variable
